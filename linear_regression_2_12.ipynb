# %%
! git clone https://github.com/ds4e/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 109 (delta 37), reused 30 (delta 30), pack-reused 63 (from 1)
# Receiving objects: 100% (109/109), 657.47 KiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Downloading course data...
# Download complete
# Extracting data files...
# Data extracted

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Linear Regression Model 

# Load the dataset
df = pd.read_csv('data/zoo.csv')
print(df.head())
# Out:
#      animal  hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# 0  aardvark     1         0     0     1         0        0         1        1
# 1  antelope     1         0     0     1         0        0         0        1
# 2      bass     0         0     1     0         0        1         1        1
# 3      bear     1         0     0     1         0        0         1        1
# 4      boar     1         0     0     1         0        0         1        1
#
#    backbone  breathes  venomous  fins  legs  tail  domestic  catsize  class
# 0         1         1         0     0     4     0         0        1      1
# 1         1         1         0     0     4     1         0        1      1
# 2         1         0         0     1     0     1         0        0      4
# 3         1         1         0     0     4     0         0        1      1
# 4         1         1         0     0     4     1         0        1      1

# %%
from statistics import LinearRegression

model = LinearRegression().fit(X, Y) # training

y_hat = model.predict(X) # prediction

#print("Mean Squared Error:", mse(Y, y_hat))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 from statistics import LinearRegression
# ----> 2 from sklearn.metrics import mean_squared_error as mse
#       4 model = LinearRegression().fit(X, Y) # training
#       6 y_hat = model.predict(X) # prediction
#
# ModuleNotFoundError: No module named 'sklearn'
