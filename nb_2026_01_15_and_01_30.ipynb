# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanrasulova/scratchpad/blob/main/nb_2026_01_15_and_01_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ayanrasulova/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 30 (delta 4), reused 1 (delta 1), pack-reused 24 (from 1)
# Receiving objects: 100% (30/30), 36.06 KiB | 3.61 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,3,5])
y = np.log(x)

plt.plot(x,y)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/content/data/sharks.csv', encoding='latin1')
# Out:
# /tmp/ipython-input-3485843008.py:3: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data/sharks.csv', encoding='latin1')

# %%
df.head()
# Out:
#    index   Case Number                  Date    Year        Type      Country  \
# 0      0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2      2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3      3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4      4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name  ... Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249  \
# ...

# %%
print(df.shape) #rows and columns
print(df.columns)

print(df.dtypes) # object = as string
print(df['Date']) # lets examine the dates..
# Out:
# (6462, 257)
# Index(['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name',
#        ...
#        'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249',
#        'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253',
#        'Unnamed: 254', 'Unnamed: 255'],
#       dtype='object', length=257)
# index             int64
# Case Number      object
# Date             object
# Year            float64
# Type             object
#                  ...
# Unnamed: 251    float64
# Unnamed: 252    float64
# Unnamed: 253    float64
# Unnamed: 254    float64
# Unnamed: 255    float64
# Length: 257, dtype: object
# 0                05-Feb-2020
# 1       Reported 30-Jan-2020
# 2                17-Jan-2020
# 3                16-Jan-2020
# 4                13-Jan-2020
#                 ...
# 6457             Before 1903
# 6458             Before 1903
# 6459               1900-1905
# 6460               1883-1889
# ...

# %%
#ok lets get the unique values of this variable

df['Date'].unique() #ah, we can see the list of values..
# lets say we had an int but it detected as string, we can see if theres commas here thats why
# Out:
# array(['05-Feb-2020', 'Reported 30-Jan-2020', '17-Jan-2020', ...,
#        '1900-1905', '1883-1889', '1845-1853'], dtype=object)

# %%
df['Year'].hist() # we can also visually see
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot()
# Out:
# []

# %%
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/data/crimebystatecombinedwithunemployment.csv', encoding='latin1')

# %%
print("\n head:")
print(df.head()) # first n rows

print("\n tail:")
print(df.tail()) # last n rows

print("\n types:")
print(df.dtypes)

print("\n shape:")
print(df.shape)

print("\n columns:")
print(df.columns)
# Out:
#  head:
#   state  unemployment  year  Population  violent total  Murder  rape  Robbery  \
# 0    AL         6.808  1976     3665000          388.8    15.1  21.7     96.0
# 1    AL         7.325  1977     3690000          414.4    14.2  25.2     96.8
# 2    AL         6.380  1978     3742000          419.1    13.3  25.5     99.1
# 3    AL         7.158  1979     3769000          413.3    13.2  27.5    109.5
# 4    AL         8.867  1980     3861466          448.5    13.2  30.0    132.1
#
#    Aggravated assault  property total  Burglary  Larceny theft  vehicle theft
# 0               256.0          3419.5    1170.0         1987.2          262.3
# 1               278.3          3298.2    1135.5         1881.9          280.7
# 2               281.2          3519.7    1229.3         1987.9          302.5
# 3               263.1          3830.5    1287.3         2223.2          320.1
# 4               273.2          4485.1    1526.7         2642.2          316.2
#
#  tail:
# ...

# %%
print(df['state'].describe())
print(df['unemployment'].describe())
# Out:
# count     1989
# unique      51
# top         AL
# freq        39
# Name: state, dtype: object
# count    1989.000000
# mean        6.127662
# std         2.080686
# min         2.300000
# 25%         4.617000
# 50%         5.800000
# 75%         7.325000
# max        17.825000
# Name: unemployment, dtype: float64

# %% [markdown]
# the fact that the value is missing is information.. if skip patterns, selection bias, bonds
#
# also think survivor bias for plane bullet holes, covid survivor bias

# %%
#df['state'].str.replace(',','') # to replace values with nothing
#df['state'] = what is listed above .. # this changes dataset
